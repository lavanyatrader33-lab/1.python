# %%
input("Enter your name:")
input("Enter your age:")
input("Enter your school name:")
input("Enter your degree:")
# Out:
# Enter your name: lavanya
# Enter your age: 14
# Enter your school name: sme
# Enter your degree: bca
# 'bca'
